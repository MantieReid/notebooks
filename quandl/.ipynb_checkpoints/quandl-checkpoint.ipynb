# %%
import quandl
import pandas as pd

# %%
quandl.ApiConfig.api_key = "xxx" #replace by your api key

# %%
# historical close prices
dfcloseprices = quandl.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date', 'close'] }, ticker = ['AAPL', 'MSFT'], date = { 'gte': '2016-01-01', 'lte': '2016-12-31' })
dfcloseprices.head()
# Out:
#      ticker       date   close
# None
# 0      AAPL 2016-01-04  105.35
# 1      AAPL 2016-01-05  102.71
# 2      AAPL 2016-01-06  100.70
# 3      AAPL 2016-01-07   96.45
# 4      AAPL 2016-01-08   96.96

# %%
# historical implied vols
dfivol = quandl.get("OPT/AAPL")
dfivol.head()
# Out:
#             stockpx   iv30   iv60   iv90  m1atmiv  m1dtex  m2atmiv  m2dtex  \
# date
# 2010-01-04   214.31  33.88  37.10  35.84    30.06    12.0    37.48    47.0
# 2010-01-05   214.27  33.27  37.22  35.90    28.07    11.0    37.65    46.0
# 2010-01-06   210.84  32.70  36.26  35.04    27.37    10.0    36.70    45.0
# 2010-01-07   210.42  32.80  36.38  34.58    26.38     9.0    37.08    44.0
# 2010-01-08   211.83  30.21  34.62  33.49    21.97     8.0    35.08    43.0
#
#             m3atmiv  m3dtex    ...     10dclsHV  20dclsHV  60dclsHV  \
# date                           ...
# 2010-01-04    35.84   103.0    ...        25.43     27.06     26.75
# 2010-01-05    35.93   102.0    ...        23.70     26.45     26.73
# 2010-01-06    35.07   101.0    ...        23.99     25.81     26.90
# 2010-01-07    34.62   100.0    ...        23.40     25.76     26.90
# 2010-01-08    33.55    99.0    ...        23.23     21.41     26.92
#
# ...

# %%
% matplotlib notebook
import matplotlib.pyplot as plt
dfivol[['iv30','iv60','iv90']][dfivol.index >= '2017-01-01'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
